# %%
# !pip install googletrans
# Out:
# ...
#   Created wheel for googletrans: filename=googletrans-2.4.0-cp36-none-any.whl size=15776 sha256=12fb12d23d5e5f253c78cd57a34f09cf852de5bebf6eaf0a1b3eed5b341927a6
#   Stored in directory: /root/.cache/pip/wheels/50/d6/e7/a8efd5f2427d5eb258070048718fa56ee5ac57fd6f53505f95
# Successfully built googletrans
# ...

# %%
import os
from googletrans import Translator
translator = Translator(service_urls=[
      'translate.google.co.uk',
      'translate.google.co.kr',
      'translate.google.ru',
      'translate.google.de',
    ])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
count = 0
folder = "tech"
for root, dirs, files in os.walk("/content/drive/My Drive/Colab Notebooks/swiggy/bbc-fulltext/bbc/" + folder + "/output/"):
    for file in files:
      file_name = os.path.join("/content/drive/My Drive/Colab Notebooks/swiggy/bbc-fulltext/bbc/" + folder + "/", file)
      #print(file_name)
      
      try:
        os.remove(file_name)
        count = count+1
      except:
        a = 0
        #print(file)
print(count)
# Out:
# 0

# %%
count = 1
for root, dirs, files in os.walk("/content/drive/My Drive/Colab Notebooks/swiggy/bbc-fulltext/bbc/" + folder + "/"):
    for file in files:
        #a = int(file.split(".")[0])
        #if a < 190:
        #    count = a
        #    continue
        print(file)
        file_name = os.path.join(root, file)
        f = open(file_name, "r", encoding = "utf-8")
        text = f.read()
        f.close()
        translation = translator.translate(text, dest = 'te')
        ans = translation.text
        file_output = open("/content/drive/My Drive/Colab Notebooks/swiggy/bbc-fulltext/bbc/" + folder + "/output/" + file, "w", encoding = 'utf-8')
        file_output.write(ans)
        file_output.close()
        print("Completed above file. " + str(count))
        count = count+1
print("Done!")
# Out:
# 056.txt
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-89143125992b> in <module>()
#      11         text = f.read()
#      12         f.close()
# ---> 13         translation = translator.translate(text, dest = 'te')
#      14         ans = translation.text
#      15         file_output = open("/content/drive/My Drive/Colab Notebooks/swiggy/bbc-fulltext/bbc/" + folder + "/output/" + file, "w", encoding = 'utf-8')
#
# /usr/local/lib/python3.6/dist-packages/googletrans/client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# /usr/local/lib/python3.6/dist-packages/googletrans/client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
# ...

# %%
types = [ "entertainment", "politics", "sport", "tech"]

for index in types:
  for root, dirs, files_2 in os.walk("/content/drive/My Drive/Colab Notebooks/swiggy/bbc-fulltext/bbc/" + index + "/output/"): 
    print("files processed under {} are {}\n".format(index, len(files_2)))
# Out:
# files processed under entertainment are 201
#
# files processed under politics are 134
#
# files processed under sport are 316
#
# files processed under tech are 73
